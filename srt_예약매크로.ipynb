# %%
# ##자동화 크롬 브라우저를 위한 필수 패키지
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time

#챗 지피티
# Chrome WebDriver 객체 생성
driver = webdriver.Chrome()

##SRT 로그인 url
login_url = 'https://etk.srail.kr/cmc/01/selectLoginForm.do'
##SRT 로그인페이지로 연결
driver.get(login_url)


## html id활용 용이하기 위해 선언
from selenium.webdriver.common.by import By

## 회원번호
custom_id_num = '1986111308'
## 회원번호 입력을 위한 Element
custom_id = driver.find_element(By.ID, 'srchDvNm01')
## 빈칸으로 초기화
custom_id.clear()
## send_keys를 통해 회원번호 입력
custom_id.send_keys(custom_id_num)


## 비밀번호
passwd_num = 'zziny7622!'
## 비밀번호 입력을 위한 Element
passwd = driver.find_element(By.ID, 'hmpgPwdCphd01')
## 빈칸으로 초기화
passwd.clear()
## send_keys를 통해 비밀번호 입력
passwd.send_keys(passwd_num)

## 확인버튼 xpath
btn_add = '/html/body/div/div[4]/div/div[2]/form/fieldset/div[1]/div[1]/div[2]/div/div[2]/input'



## 확인버튼 클릭을 위한 Element
login_btn = driver.find_element(By.XPATH, btn_add)
## 확인버튼 클릭
login_btn.click()



time.sleep(2)
##승차권 예약으로 접속
driver.get('https://etk.srail.kr/hpg/hra/01/selectScheduleList.do?pageId=TK0101010000')

## 지역명 예시
station_list = ['수서','동탄','평택지제','천안아산','오송',
                '대전','김천(구미)','서대구','동대구','신경주',
                '울산(통도사)','부산','공주','익산','정읍','광주송정','나주','목포']

def train_info():
    
    ##출발지 선택
    ##출발지 정보
    departure_areaName = "동대구"                      # ★★★★★★★★★★★★★★ 출발지
    ##출발지 입력을 위한 Element
    departure_area = driver.find_element(By.ID, 'dptRsStnCdNm')
    ##사전에 입력된 내용 지우기
    departure_area.clear()
    ##출발지 입력
    departure_area.send_keys(departure_areaName)
    
    ##도착지 선택
    ##도착지 정보
    arrival_areaName = "수서"                      # ★★★★★★★★★★★★★★ 도착지
    ##도착지 입력을 위한 Element
    arrival_area = driver.find_element(By.ID, 'arvRsStnCdNm')
    ##사전에 입력된 내용 지우기
    arrival_area.clear()
    ##도착지 입력
    arrival_area.send_keys(arrival_areaName)
    
    ##리스트를 포함하는 Element를 다루기 위한 package선언
    from selenium.webdriver.support.select import Select
    ##출발일자 선택
    ##출발일자
    target_date = 20240211                      # ★★★★★★★★★★★★★★ 탑승일자
    ##출발지 입력을 위한 Element
    departure_date = driver.find_element(By.ID, 'dptDt')
    
    ##숫자로 입력 없거나 에러이면 오늘로 진행
    try:
        ##일자 리스트 중에서 출발일자 선택
        Select(departure_date).select_by_value(str(target_date))
    except:
        ##오늘년월일 정보 입력
        today = datetime.now().strftime('%Y%m%d')
        ##일자 리스트 중에서 오늘을 선택
        Select(departure_date).select_by_value(str(today))
    
    ##출발시간 선택
    ##출발시간
    target_time = 16                              # ★★★★★★★★★★★★★★ 출발시각
    
    ## 문자열 구성을 위해 10 미만은 문자 0을 앞에 추가
    if target_time < 10:
        target_time = '0'+ str(target_time)
    else:
        target_time = str(target_time)
    
    ##출발시간 입력을 위한 Element
    departure_time = driver.find_element(By.ID, 'dptTm')
    
    
    try:
        ## 타겟 시간 선택
        Select(departure_time).select_by_value(target_time+ '0000')
    except:
        pass
    
    ##어른 탑승객 수
    adult_num = 1
    ##어른탑승객수 Element xpath (id가 아닌 xpath형태로 코드구현)
    adult_select_add = '/html/body/div[1]/div[4]/div/div[2]/form/fieldset/div[1]/div/ul/li[2]/div[2]/div[1]/select'
    ##어른 탑승객 수를 위한 Element
    adult_passenger = driver.find_element(By.XPATH, adult_select_add)
    # login_btn = driver.find_element(By.XPATH, btn_add)
    
    ##어른 탑승객 수 선택
    try:
        Select(adult_passenger).select_by_value(str(adult_num))
    except:
        ## 에러가 나면 탑승객수 0명으로 선택
        Select(adult_passenger).select_by_value(str(0))
    
    
    ##SRT차량선택
    srt_select_radio_btn = driver.find_element(By.ID, 'trnGpCd300')
    srt_select_radio_btn.click()

train_info()

# %%
#조회버튼클릭
search_btn = "/html/body/div/div[4]/div/div[2]/form/fieldset/div[2]/input"
driver.find_element(By.XPATH, search_btn).click()


#sleep을 위해서 time package 선언
import time
## 대기자수 많아서 웨이팅 후 예매선택
train_schedule_add = '/html/body/div/div[4]/div/div[3]/div[1]/form/fieldset/div[6]/table/tbody/tr[1]/td[10]/a' #원래코드
def page_stable():
    for i in range(60):
        time.sleep(1.5)
        try:
            # driver.find_element(By.XPATH, waiting_list)
            driver.find_element(By.XPATH, train_schedule_add)
            print('대기 끝')
            break
        except:
            i+=1
            print('대기 중: ', i, " 초")
            pass
        # time.sleep(1.5)
    time.sleep(1.5)

# 사용자 정의 함수 실행
page_stable()

##예약이 될때까지 반복문수행
n=1
search_button_found = False
while True:
    try:
        for i in range(5, 11):  # 타고싶은 후보 열차 입력 (위에서 부터 1번)
            standard_seat = driver.find_element(By.CSS_SELECTOR, f"#result-form > fieldset > div.tbl_wrap.th_thead > table > tbody > tr:nth-child({i}) > td:nth-child(7)").text
    
            if "예약하기" in standard_seat:
                driver.find_element(By.XPATH, f"/html/body/div[1]/div[4]/div/div[3]/div[1]/form/fieldset/div[6]/table/tbody/tr[{i}]/td[7]/a/span").click()
                print("예약 가능")
                # driver.implicitly_wait(3)
    
                if driver.find_elements(By.ID, 'isFalseGotoMain'):
                    is_booked = True
                    print("예약 성공")
                    break
                else:
                    print("잔여석 없음")
                    driver.back() # 뒤로 가기
                    driver.implicitly_wait(3)
        # time.sleep(2)

    except:
        # 리스트 초기화 됐을때, 다시 조회버튼 누르고 루프 반복
        driver.find_element(By.XPATH, search_btn)
        # search_button_found = True
        print("열차 리스트가 초기화 되었습니다.\n")
        driver.find_element(By.XPATH, search_btn).click()
        page_stable()
        # time.sleep(2)
    
    #새로고침 후 다시 루프 반복
    time.sleep(2.5)
    driver.refresh()
    n+=1
    print("새로고침 " , n, " 회")


print('book finished')
# Out:
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 끝
# 새로고침  2  회
# 새로고침  3  회
# 새로고침  4  회
# 새로고침  5  회
# 새로고침  6  회
# 새로고침  7  회
# 새로고침  8  회
# 새로고침  9  회
# 새로고침  10  회
# 새로고침  11  회
# 새로고침  12  회
# 새로고침  13  회
# 새로고침  14  회
# 새로고침  15  회
# 새로고침  16  회
# 새로고침  17  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 중:  30  초
# 대기 중:  31  초
# 대기 중:  32  초
# 대기 중:  33  초
# 대기 끝
# 새로고침  18  회
# 새로고침  19  회
# 새로고침  20  회
# 새로고침  21  회
# 새로고침  22  회
# 새로고침  23  회
# 새로고침  24  회
# 새로고침  25  회
# 새로고침  26  회
# 새로고침  27  회
# 새로고침  28  회
# 새로고침  29  회
# 새로고침  30  회
# 새로고침  31  회
# 새로고침  32  회
# 새로고침  33  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 중:  30  초
# 대기 중:  31  초
# 대기 중:  32  초
# 대기 중:  33  초
# 대기 중:  34  초
# 대기 중:  35  초
# 대기 중:  36  초
# 대기 끝
# 새로고침  34  회
# 새로고침  35  회
# 새로고침  36  회
# 새로고침  37  회
# 새로고침  38  회
# 새로고침  39  회
# 새로고침  40  회
# 새로고침  41  회
# 새로고침  42  회
# 새로고침  43  회
# 새로고침  44  회
# 새로고침  45  회
# 새로고침  46  회
# 새로고침  47  회
# 새로고침  48  회
# 새로고침  49  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 중:  30  초
# 대기 중:  31  초
# 대기 중:  32  초
# 대기 중:  33  초
# 대기 끝
# 새로고침  50  회
# 새로고침  51  회
# 새로고침  52  회
# 새로고침  53  회
# 새로고침  54  회
# 새로고침  55  회
# 새로고침  56  회
# 새로고침  57  회
# 새로고침  58  회
# 새로고침  59  회
# 새로고침  60  회
# 새로고침  61  회
# 새로고침  62  회
# 새로고침  63  회
# 새로고침  64  회
# 새로고침  65  회
# 새로고침  66  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 중:  30  초
# 대기 중:  31  초
# 대기 중:  32  초
# 대기 중:  33  초
# 대기 끝
# 새로고침  67  회
# 새로고침  68  회
# 새로고침  69  회
# 새로고침  70  회
# 새로고침  71  회
# 새로고침  72  회
# 새로고침  73  회
# 새로고침  74  회
# 새로고침  75  회
# 새로고침  76  회
# 새로고침  77  회
# 새로고침  78  회
# 새로고침  79  회
# 새로고침  80  회
# 새로고침  81  회
# 새로고침  82  회
# 새로고침  83  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 중:  30  초
# 대기 중:  31  초
# 대기 중:  32  초
# 대기 중:  33  초
# 대기 끝
# 새로고침  84  회
# 새로고침  85  회
# 새로고침  86  회
# 새로고침  87  회
# 새로고침  88  회
# 새로고침  89  회
# 새로고침  90  회
# 새로고침  91  회
# 새로고침  92  회
# 새로고침  93  회
# 새로고침  94  회
# 새로고침  95  회
# 새로고침  96  회
# 새로고침  97  회
# 새로고침  98  회
# 새로고침  99  회
# 새로고침  100  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 중:  30  초
# 대기 중:  31  초
# 대기 중:  32  초
# 대기 중:  33  초
# 대기 끝
# 새로고침  101  회
# 새로고침  102  회
# 새로고침  103  회
# 새로고침  104  회
# 새로고침  105  회
# 새로고침  106  회
# 새로고침  107  회
# 새로고침  108  회
# 새로고침  109  회
# 새로고침  110  회
# 새로고침  111  회
# 새로고침  112  회
# 새로고침  113  회
# 새로고침  114  회
# 새로고침  115  회
# 새로고침  116  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 중:  30  초
# 대기 중:  31  초
# 대기 끝
# 새로고침  117  회
# 새로고침  118  회
# 새로고침  119  회
# 새로고침  120  회
# 새로고침  121  회
# 새로고침  122  회
# 새로고침  123  회
# 새로고침  124  회
# 새로고침  125  회
# 새로고침  126  회
# 새로고침  127  회
# 새로고침  128  회
# 새로고침  129  회
# 새로고침  130  회
# 새로고침  131  회
# 새로고침  132  회
# 새로고침  133  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 끝
# 새로고침  134  회
# 새로고침  135  회
# 새로고침  136  회
# 새로고침  137  회
# 새로고침  138  회
# 새로고침  139  회
# 새로고침  140  회
# 새로고침  141  회
# 새로고침  142  회
# 새로고침  143  회
# 새로고침  144  회
# 새로고침  145  회
# 새로고침  146  회
# 새로고침  147  회
# 새로고침  148  회
# 새로고침  149  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 끝
# 새로고침  150  회
# 새로고침  151  회
# 새로고침  152  회
# 새로고침  153  회
# 새로고침  154  회
# 새로고침  155  회
# 새로고침  156  회
# 새로고침  157  회
# 새로고침  158  회
# 새로고침  159  회
# 새로고침  160  회
# 새로고침  161  회
# 새로고침  162  회
# 새로고침  163  회
# 새로고침  164  회
# 새로고침  165  회
# 새로고침  166  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 끝
# 새로고침  167  회
# 새로고침  168  회
# 새로고침  169  회
# 새로고침  170  회
# 새로고침  171  회
# 새로고침  172  회
# 새로고침  173  회
# 새로고침  174  회
# 새로고침  175  회
# 새로고침  176  회
# 새로고침  177  회
# 새로고침  178  회
# 새로고침  179  회
# 새로고침  180  회
# 새로고침  181  회
# 새로고침  182  회
# 새로고침  183  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 중:  30  초
# 대기 중:  31  초
# 대기 중:  32  초
# 대기 끝
# 새로고침  184  회
# 새로고침  185  회
# 새로고침  186  회
# 새로고침  187  회
# 새로고침  188  회
# 새로고침  189  회
# 새로고침  190  회
# 새로고침  191  회
# 새로고침  192  회
# 새로고침  193  회
# 새로고침  194  회
# 새로고침  195  회
# 새로고침  196  회
# 새로고침  197  회
# 새로고침  198  회
# 새로고침  199  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 중:  30  초
# 대기 중:  31  초
# 대기 중:  32  초
# 대기 중:  33  초
# 대기 중:  34  초
# 대기 중:  35  초
# 대기 중:  36  초
# 대기 끝
# 새로고침  200  회
# 새로고침  201  회
# 새로고침  202  회
# 새로고침  203  회
# 새로고침  204  회
# 새로고침  205  회
# 새로고침  206  회
# 새로고침  207  회
# 새로고침  208  회
# 새로고침  209  회
# 새로고침  210  회
# 새로고침  211  회
# 새로고침  212  회
# 새로고침  213  회
# 새로고침  214  회
# 새로고침  215  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 중:  30  초
# 대기 중:  31  초
# 대기 중:  32  초
# 대기 중:  33  초
# 대기 중:  34  초
# 대기 중:  35  초
# 대기 중:  36  초
# 대기 중:  37  초
# 대기 중:  38  초
# 대기 끝
# 새로고침  216  회
# 새로고침  217  회
# 새로고침  218  회
# 새로고침  219  회
# 새로고침  220  회
# 새로고침  221  회
# 새로고침  222  회
# 새로고침  223  회
# 새로고침  224  회
# 새로고침  225  회
# 새로고침  226  회
# 새로고침  227  회
# 새로고침  228  회
# 새로고침  229  회
# 새로고침  230  회
# 새로고침  231  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 중:  30  초
# 대기 중:  31  초
# 대기 중:  32  초
# 대기 중:  33  초
# 대기 중:  34  초
# 대기 중:  35  초
# 대기 중:  36  초
# 대기 중:  37  초
# 대기 중:  38  초
# 대기 중:  39  초
# 대기 중:  40  초
# 대기 중:  41  초
# 대기 끝
# 새로고침  232  회
# 새로고침  233  회
# 새로고침  234  회
# 새로고침  235  회
# 새로고침  236  회
# 새로고침  237  회
# 새로고침  238  회
# 새로고침  239  회
# 새로고침  240  회
# 새로고침  241  회
# 새로고침  242  회
# 새로고침  243  회
# 새로고침  244  회
# 새로고침  245  회
# 새로고침  246  회
# 새로고침  247  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 중:  30  초
# 대기 중:  31  초
# 대기 끝
# 새로고침  248  회
# 새로고침  249  회
# 새로고침  250  회
# 새로고침  251  회
# 새로고침  252  회
# 새로고침  253  회
# 새로고침  254  회
# 새로고침  255  회
# 새로고침  256  회
# 새로고침  257  회
# 새로고침  258  회
# 새로고침  259  회
# 새로고침  260  회
# 새로고침  261  회
# 새로고침  262  회
# 새로고침  263  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 끝
# 새로고침  264  회
# 새로고침  265  회
# 새로고침  266  회
# 새로고침  267  회
# 새로고침  268  회
# 새로고침  269  회
# 새로고침  270  회
# 새로고침  271  회
# 새로고침  272  회
# 새로고침  273  회
# 새로고침  274  회
# 새로고침  275  회
# 새로고침  276  회
# 새로고침  277  회
# 새로고침  278  회
# 새로고침  279  회
# 새로고침  280  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 끝
# 새로고침  281  회
# 새로고침  282  회
# 새로고침  283  회
# 새로고침  284  회
# 새로고침  285  회
# 새로고침  286  회
# 새로고침  287  회
# 새로고침  288  회
# 새로고침  289  회
# 새로고침  290  회
# 새로고침  291  회
# 새로고침  292  회
# 새로고침  293  회
# 새로고침  294  회
# 새로고침  295  회
# 새로고침  296  회
# 새로고침  297  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 끝
# 새로고침  298  회
# 새로고침  299  회
# 새로고침  300  회
# 새로고침  301  회
# 새로고침  302  회
# 새로고침  303  회
# 새로고침  304  회
# 새로고침  305  회
# 새로고침  306  회
# 새로고침  307  회
# 새로고침  308  회
# 새로고침  309  회
# 새로고침  310  회
# 새로고침  311  회
# 새로고침  312  회
# 새로고침  313  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 중:  30  초
# 대기 중:  31  초
# 대기 중:  32  초
# 대기 중:  33  초
# 대기 중:  34  초
# 대기 중:  35  초
# 대기 중:  36  초
# 대기 중:  37  초
# 대기 중:  38  초
# 대기 중:  39  초
# 대기 중:  40  초
# 대기 중:  41  초
# 대기 중:  42  초
# 대기 중:  43  초
# 대기 중:  44  초
# 대기 중:  45  초
# 대기 중:  46  초
# 대기 중:  47  초
# 대기 끝
# 새로고침  314  회
# 새로고침  315  회
# 새로고침  316  회
# 새로고침  317  회
# 새로고침  318  회
# 새로고침  319  회
# 새로고침  320  회
# 새로고침  321  회
# 새로고침  322  회
# 새로고침  323  회
# 새로고침  324  회
# 새로고침  325  회
# 새로고침  326  회
# 새로고침  327  회
# 새로고침  328  회
# 새로고침  329  회
# 새로고침  330  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 중:  30  초
# 대기 끝
# 새로고침  331  회
# 새로고침  332  회
# 새로고침  333  회
# 새로고침  334  회
# 새로고침  335  회
# 새로고침  336  회
# 새로고침  337  회
# 새로고침  338  회
# 새로고침  339  회
# 새로고침  340  회
# 새로고침  341  회
# 새로고침  342  회
# 새로고침  343  회
# 새로고침  344  회
# 새로고침  345  회
# 새로고침  346  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 중:  30  초
# 대기 중:  31  초
# 대기 중:  32  초
# 대기 중:  33  초
# 대기 중:  34  초
# 대기 중:  35  초
# 대기 중:  36  초
# 대기 중:  37  초
# 대기 중:  38  초
# 대기 중:  39  초
# 대기 중:  40  초
# 대기 중:  41  초
# 대기 중:  42  초
# 대기 중:  43  초
# 대기 중:  44  초
# 대기 중:  45  초
# 대기 중:  46  초
# 대기 중:  47  초
# 대기 중:  48  초
# 대기 중:  49  초
# 대기 끝
# 새로고침  347  회
# 새로고침  348  회
# 새로고침  349  회
# 새로고침  350  회
# 새로고침  351  회
# 새로고침  352  회
# 새로고침  353  회
# 새로고침  354  회
# 새로고침  355  회
# 새로고침  356  회
# 새로고침  357  회
# 새로고침  358  회
# 새로고침  359  회
# 새로고침  360  회
# 새로고침  361  회
# 새로고침  362  회
# 새로고침  363  회
# 열차 리스트가 초기화 되었습니다.
#
# 대기 중:  1  초
# 대기 중:  2  초
# 대기 중:  3  초
# 대기 중:  4  초
# 대기 중:  5  초
# 대기 중:  6  초
# 대기 중:  7  초
# 대기 중:  8  초
# 대기 중:  9  초
# 대기 중:  10  초
# 대기 중:  11  초
# 대기 중:  12  초
# 대기 중:  13  초
# 대기 중:  14  초
# 대기 중:  15  초
# 대기 중:  16  초
# 대기 중:  17  초
# 대기 중:  18  초
# 대기 중:  19  초
# 대기 중:  20  초
# 대기 중:  21  초
# 대기 중:  22  초
# 대기 중:  23  초
# 대기 중:  24  초
# 대기 중:  25  초
# 대기 중:  26  초
# 대기 중:  27  초
# 대기 중:  28  초
# 대기 중:  29  초
# 대기 중:  30  초
# 대기 중:  31  초
# 대기 중:  32  초
# 대기 중:  33  초
# 대기 중:  34  초
# 대기 중:  35  초
# 대기 중:  36  초
# 대기 중:  37  초
# 대기 중:  38  초
# 대기 끝
# 새로고침  364  회
# 새로고침  365  회
# 새로고침  366  회
# 새로고침  367  회
# 새로고침  368  회
# 새로고침  369  회
# 새로고침  370  회
# 새로고침  371  회
# 새로고침  372  회
# 새로고침  373  회
# 새로고침  374  회
# 새로고침  375  회
# 새로고침  376  회
# 새로고침  377  회
# 새로고침  378  회
# 예약 가능
# 예약 성공
# 새로고침  379  회
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[12], line 34
#      33 for i in range(5, 11):  # 타고싶은 후보 열차 입력 (위에서 부터 1번)
# ---> 34     standard_seat = driver.find_element(By.CSS_SELECTOR, f"#result-form > fieldset > div.tbl_wrap.th_thead > table > tbody > tr:nth-child({i}) > td:nth-child(7)").text
#      36     if "예약하기" in standard_seat:
#
# File C:\Program Files\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File C:\Program Files\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#
# File C:\Program Files\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#result-form > fieldset > div.tbl_wrap.th_thead > table > tbody > tr:nth-child(5) > td:nth-child(7)"}
#   (Session info: chrome=121.0.6167.161); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF63D425E42+3538674]
# 	(No symbol) [0x00007FF63D044C02]
# 	(No symbol) [0x00007FF63CEF5AEB]
# 	(No symbol) [0x00007FF63CF3BF4E]
# 	(No symbol) [0x00007FF63CF3C0CC]
# 	(No symbol) [0x00007FF63CF7E477]
# 	(No symbol) [0x00007FF63CF5F0EF]
# 	(No symbol) [0x00007FF63CF7BDE3]
# 	(No symbol) [0x00007FF63CF5EE53]
# 	(No symbol) [0x00007FF63CF2F514]
# 	(No symbol) [0x00007FF63CF30631]
# 	GetHandleVerifier [0x00007FF63D456CAD+3738973]
# 	GetHandleVerifier [0x00007FF63D4AC506+4089270]
# 	GetHandleVerifier [0x00007FF63D4A4823+4057299]
# 	GetHandleVerifier [0x00007FF63D175C49+720121]
# 	(No symbol) [0x00007FF63D05126F]
# 	(No symbol) [0x00007FF63D04C304]
# 	(No symbol) [0x00007FF63D04C432]
# 	(No symbol) [0x00007FF63D03BD04]
# 	BaseThreadInitThunk [0x00007FF9C8627614+20]
# 	RtlUserThreadStart [0x00007FF9C87626A1+33]
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[12], line 53
#      49     # time.sleep(2)
#      51 except:
#      52     # 리스트 초기화 됐을때, 다시 조회버튼 누르고 루프 반복
# ---> 53     driver.find_element(By.XPATH, search_btn)
#      54     # search_button_found = True
#      55     print("열차 리스트가 초기화 되었습니다.\n")
#
# File C:\Program Files\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File C:\Program Files\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File C:\Program Files\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div/div[4]/div/div[2]/form/fieldset/div[2]/input"}
#   (Session info: chrome=121.0.6167.161); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF63D425E42+3538674]
# 	(No symbol) [0x00007FF63D044C02]
# 	(No symbol) [0x00007FF63CEF5AEB]
# 	(No symbol) [0x00007FF63CF3BF4E]
# 	(No symbol) [0x00007FF63CF3C0CC]
# 	(No symbol) [0x00007FF63CF7E477]
# 	(No symbol) [0x00007FF63CF5F0EF]
# 	(No symbol) [0x00007FF63CF7BDE3]
# 	(No symbol) [0x00007FF63CF5EE53]
# 	(No symbol) [0x00007FF63CF2F514]
# 	(No symbol) [0x00007FF63CF30631]
# 	GetHandleVerifier [0x00007FF63D456CAD+3738973]
# 	GetHandleVerifier [0x00007FF63D4AC506+4089270]
# 	GetHandleVerifier [0x00007FF63D4A4823+4057299]
# 	GetHandleVerifier [0x00007FF63D175C49+720121]
# 	(No symbol) [0x00007FF63D05126F]
# 	(No symbol) [0x00007FF63D04C304]
# 	(No symbol) [0x00007FF63D04C432]
# 	(No symbol) [0x00007FF63D03BD04]
# 	BaseThreadInitThunk [0x00007FF9C8627614+20]
# 	RtlUserThreadStart [0x00007FF9C87626A1+33]
