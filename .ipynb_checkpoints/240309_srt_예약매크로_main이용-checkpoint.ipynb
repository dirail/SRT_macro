# %%
# ##자동화 크롬 브라우저를 위한 필수 패키지
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By   ## html id활용 용이하기 위해 선언
from selenium.webdriver.support.select import Select    ## 리스트를 포함하는 Element를 다루기 위한 package선언
import time     #sleep을 위해서 time package 선언

# Chrome WebDriver 객체 생성
def open_browser():    
    driver = webdriver.Chrome()
    return driver

# 로그인 함수
def login(driver, login_id, login_pw):
    driver.get('https://etk.srail.kr/cmc/01/selectLoginForm.do')    ## SRT 로그인페이지로 연결
    driver.find_element(By.ID, 'srchDvNm01').send_keys(str(login_id))    ## 회원번호 입력
    driver.find_element(By.ID, 'hmpgPwdCphd01').send_keys(str(login_pw))    ## 비밀번호 입력
    ## 확인버튼 클릭
    driver.find_element(By.XPATH, '/html/body/div/div[4]/div/div[2]/form/fieldset/div[1]/div[1]/div[2]/div/div[2]/input').click()
    return driver

# 기차 정보 셋팅 함수
def set_train(driver, dpt_stn, arr_stn, dpt_dt, dpt_tm,  psn_num = 1, want_reserve=False):

    ## 승차권 예약으로 접속
    driver.get('https://etk.srail.kr/hpg/hra/01/selectScheduleList.do?pageId=TK0101010000')

    ## 출발지 선택
    elm_dpt_stn = driver.find_element(By.ID, 'dptRsStnCdNm')
    elm_dpt_stn.clear()     ##사전에 입력된 내용 지우기
    elm_dpt_stn.send_keys(dpt_stn)
    
    ## 도착지 선택
    elm_arr_stn = driver.find_element(By.ID, 'arvRsStnCdNm')
    elm_arr_stn.clear()
    elm_arr_stn.send_keys(arr_stn)
    
    ##출발일자 선택
    elm_dptDt = driver.find_element(By.ID, 'dptDt')    
    ##숫자로 입력 없거나 에러이면 오늘로 진행
    try:
        ##일자 리스트 중에서 출발일자 선택
        Select(elm_dptDt).select_by_value(str(dpt_dt))
    except:
        ##오늘년월일 정보 입력
        today = datetime.now().strftime('%Y%m%d')
        Select(elm_dptDt).select_by_value(str(today))
    
    ## 출발시각 선택 & 전처리 : 문자열 구성을 위해 10 미만은 문자 0을 앞에 추가
    if dpt_tm  < 10:
        dpt_tm  = '0'+ str(dpt_tm)
    else:
        dpt_tm  = str(dpt_tm)

    ##출발시각 입력을 위한 Element
    elm_dptTm  = driver.find_element(By.ID, 'dptTm')  
    try:
        Select(elm_dptTm).select_by_value(dpt_tm + '0000')      ## 타겟 시간 선택
    except:
        pass
    
    ## 기차종류 SRT만 선택 
    driver.find_element(By.ID, 'trnGpCd300').click()

    # # 알림
    print("기차를 조회합니다")
    print(f"출발역 [{dpt_stn}] / 도착역 [{arr_stn}]\n{dpt_dt[:4]}년 {dpt_dt[4:6]}월 {dpt_dt[6:]}일")

    return driver

# %%
# 조회 루프 시작
def page_stable():
    ## 대기자수 많아서 웨이팅 후 예매선택 ( 조회 성공시 나오는 열차번호? 안 나오면 계속 기다리는 원리 )
    for i in range(40):
        time.sleep(1.0)
        try:
            # driver.find_element(By.XPATH, waiting_list)
            driver.find_element(By.XPATH, '/html/body/div/div[4]/div/div[3]/div[1]/form/fieldset/div[6]/table/tbody/tr[1]/td[10]/a')
            # print('대기 끝')
            break
        except:
            print('대기 중 .... ', i)
            pass
        # time.sleep(1.5)
    time.sleep(1.5)


def start_search(first = 1, last = 10):

    #조회버튼클릭
    search_btn = "/html/body/div/div[4]/div/div[2]/form/fieldset/div[2]/input"
    driver.find_element(By.XPATH, search_btn).click()

    page_stable()

    first_train = driver.find_element(By.CSS_SELECTOR, f"#result-form > fieldset > div.tbl_wrap.th_thead > table > tbody > tr:nth-child({first}) > td:nth-child({4})").text[-5:]
    last_train = driver.find_element(By.CSS_SELECTOR, f"#result-form > fieldset > div.tbl_wrap.th_thead > table > tbody > tr:nth-child({last}) > td:nth-child({4})").text[-5:]
    print( f"{first_train}에서 {last_train} 사이의 기차를 조회합니다.\n" )
    
    ##예약이 될때까지 반복문수행
    n=0
    search_button_found = False
    while True:
        try:  # try 가 트루가 되면 끝나는겨
            for i in range(first, last + 1):  # 타고싶은 후보 열차 입력 (위에서 부터 1번)
                standard_seat = driver.find_element(By.CSS_SELECTOR, f"#result-form > fieldset > div.tbl_wrap.th_thead > table > tbody > tr:nth-child({i}) > td:nth-child(7)").text
    
                if "예약하기" in standard_seat:
                    driver.find_element(By.XPATH, f"/html/body/div[1]/div[4]/div/div[3]/div[1]/form/fieldset/div[6]/table/tbody/tr[{i}]/td[7]/a/span").click()
                    print("예약 가능")
                    break
            n+=1
            print( f'재시도 ...... {n:03}' )
            # pass
    
        except:
            # 리스트 초기화 됐을때
            driver.find_element(By.XPATH, search_btn)
            # search_button_found = True
            print("열차 리스트가 초기화 되었습니다.\n")
            driver.find_element(By.XPATH, search_btn).click()
    
            page_stable()
            # time.sleep(2)
    
            ##자리나서 눌렀는데 잔여석 없다고 나올때
        try:
            # no_empty = "/html/body/div/div[4]/div/div[2]/div[7]/a"
            no_empty = "//a[@class='btn_large btn_blue val_m']/span[text()='확인']"
            no_empty_btn = driver.find_element(By.XPATH, no_empty)
            no_empty_btn
            driver.back()
            print("잔여좌석 없음")
            ## 원하는 기차정보 재셋팅 필요
            time.sleep(2)
        except:
            # print('확인 버튼을 찾을 수 없습니다.')
            pass
        search_button_found = False
        time.sleep(2.5)
        driver.refresh()

    return driver

# %%
## 지역명 예시
# ['수서','동탄','평택지제','천안아산','오송',
# '대전','김천(구미)','서대구','동대구','신경주',
# '울산(통도사)','부산','공주','익산','정읍','광주송정','나주','목포']


if __name__ == "__main__":
    driver = open_browser()
    driver = login(driver, '1986111308', 'zziny7622!')  ## 회원 번호, 비밀번호
    set_train(driver, "동대구", "수서", "20240310", 16)  ## ex) "동대구", "수서", "20240310", 16(탑승시각)
    start_search(first = 5, last = 7)  ## 화면 중 원하는 시간대 선택가능, 기본값 first = 1, last = 10
    print('예약 완료')
# Out:
# 16:53에서 18:18 사이의 기차를 조회합니다.
#
# 재시도 ...... 001
# 재시도 ...... 002
# 재시도 ...... 003
# 재시도 ...... 004
# 재시도 ...... 005
# 재시도 ...... 006
# 재시도 ...... 007
# 재시도 ...... 008
# 재시도 ...... 009
# 재시도 ...... 010
# 재시도 ...... 011
# 재시도 ...... 012
# 재시도 ...... 013
# 재시도 ...... 014
# 재시도 ...... 015
# 재시도 ...... 016
# 재시도 ...... 017
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 018
# 재시도 ...... 019
# 재시도 ...... 020
# 재시도 ...... 021
# 재시도 ...... 022
# 재시도 ...... 023
# 재시도 ...... 024
# 재시도 ...... 025
# 재시도 ...... 026
# 재시도 ...... 027
# 재시도 ...... 028
# 재시도 ...... 029
# 재시도 ...... 030
# 재시도 ...... 031
# 재시도 ...... 032
# 재시도 ...... 033
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 034
# 재시도 ...... 035
# 재시도 ...... 036
# 재시도 ...... 037
# 재시도 ...... 038
# 재시도 ...... 039
# 재시도 ...... 040
# 재시도 ...... 041
# 재시도 ...... 042
# 재시도 ...... 043
# 재시도 ...... 044
# 재시도 ...... 045
# 재시도 ...... 046
# 재시도 ...... 047
# 재시도 ...... 048
# 재시도 ...... 049
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 050
# 재시도 ...... 051
# 재시도 ...... 052
# 재시도 ...... 053
# 재시도 ...... 054
# 재시도 ...... 055
# 재시도 ...... 056
# 재시도 ...... 057
# 재시도 ...... 058
# 재시도 ...... 059
# 재시도 ...... 060
# 재시도 ...... 061
# 재시도 ...... 062
# 재시도 ...... 063
# 재시도 ...... 064
# 재시도 ...... 065
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 066
# 재시도 ...... 067
# 재시도 ...... 068
# 재시도 ...... 069
# 재시도 ...... 070
# 재시도 ...... 071
# 재시도 ...... 072
# 재시도 ...... 073
# 재시도 ...... 074
# 재시도 ...... 075
# 재시도 ...... 076
# 재시도 ...... 077
# 재시도 ...... 078
# 재시도 ...... 079
# 재시도 ...... 080
# 재시도 ...... 081
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 082
# 재시도 ...... 083
# 재시도 ...... 084
# 재시도 ...... 085
# 재시도 ...... 086
# 재시도 ...... 087
# 재시도 ...... 088
# 재시도 ...... 089
# 재시도 ...... 090
# 재시도 ...... 091
# 재시도 ...... 092
# 재시도 ...... 093
# 재시도 ...... 094
# 재시도 ...... 095
# 재시도 ...... 096
# 재시도 ...... 097
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 098
# 재시도 ...... 099
# 재시도 ...... 100
# 재시도 ...... 101
# 재시도 ...... 102
# 재시도 ...... 103
# 재시도 ...... 104
# 재시도 ...... 105
# 재시도 ...... 106
# 재시도 ...... 107
# 재시도 ...... 108
# 재시도 ...... 109
# 재시도 ...... 110
# 재시도 ...... 111
# 재시도 ...... 112
# 재시도 ...... 113
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 114
# 재시도 ...... 115
# 재시도 ...... 116
# 재시도 ...... 117
# 재시도 ...... 118
# 재시도 ...... 119
# 재시도 ...... 120
# 재시도 ...... 121
# 재시도 ...... 122
# 재시도 ...... 123
# 재시도 ...... 124
# 재시도 ...... 125
# 재시도 ...... 126
# 재시도 ...... 127
# 재시도 ...... 128
# 재시도 ...... 129
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 130
# 재시도 ...... 131
# 재시도 ...... 132
# 재시도 ...... 133
# 재시도 ...... 134
# 재시도 ...... 135
# 재시도 ...... 136
# 재시도 ...... 137
# 재시도 ...... 138
# 재시도 ...... 139
# 재시도 ...... 140
# 재시도 ...... 141
# 재시도 ...... 142
# 재시도 ...... 143
# 재시도 ...... 144
# 재시도 ...... 145
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 146
# 재시도 ...... 147
# 재시도 ...... 148
# 재시도 ...... 149
# 재시도 ...... 150
# 재시도 ...... 151
# 재시도 ...... 152
# 재시도 ...... 153
# 재시도 ...... 154
# 재시도 ...... 155
# 재시도 ...... 156
# 재시도 ...... 157
# 재시도 ...... 158
# 재시도 ...... 159
# 재시도 ...... 160
# 재시도 ...... 161
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 162
# 재시도 ...... 163
# 재시도 ...... 164
# 재시도 ...... 165
# 재시도 ...... 166
# 재시도 ...... 167
# 재시도 ...... 168
# 재시도 ...... 169
# 재시도 ...... 170
# 재시도 ...... 171
# 재시도 ...... 172
# 재시도 ...... 173
# 재시도 ...... 174
# 재시도 ...... 175
# 재시도 ...... 176
# 재시도 ...... 177
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 178
# 재시도 ...... 179
# 재시도 ...... 180
# 재시도 ...... 181
# 재시도 ...... 182
# 재시도 ...... 183
# 재시도 ...... 184
# 재시도 ...... 185
# 재시도 ...... 186
# 재시도 ...... 187
# 재시도 ...... 188
# 재시도 ...... 189
# 재시도 ...... 190
# 재시도 ...... 191
# 재시도 ...... 192
# 재시도 ...... 193
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 194
# 재시도 ...... 195
# 재시도 ...... 196
# 재시도 ...... 197
# 재시도 ...... 198
# 재시도 ...... 199
# 재시도 ...... 200
# 재시도 ...... 201
# 재시도 ...... 202
# 재시도 ...... 203
# 재시도 ...... 204
# 재시도 ...... 205
# 재시도 ...... 206
# 재시도 ...... 207
# 재시도 ...... 208
# 재시도 ...... 209
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 210
# 재시도 ...... 211
# 재시도 ...... 212
# 재시도 ...... 213
# 재시도 ...... 214
# 재시도 ...... 215
# 재시도 ...... 216
# 재시도 ...... 217
# 재시도 ...... 218
# 재시도 ...... 219
# 재시도 ...... 220
# 재시도 ...... 221
# 재시도 ...... 222
# 재시도 ...... 223
# 재시도 ...... 224
# 재시도 ...... 225
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 226
# 재시도 ...... 227
# 재시도 ...... 228
# 재시도 ...... 229
# 재시도 ...... 230
# 재시도 ...... 231
# 재시도 ...... 232
# 재시도 ...... 233
# 재시도 ...... 234
# 재시도 ...... 235
# 재시도 ...... 236
# 재시도 ...... 237
# 재시도 ...... 238
# 재시도 ...... 239
# 재시도 ...... 240
# 재시도 ...... 241
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 242
# 재시도 ...... 243
# 재시도 ...... 244
# 재시도 ...... 245
# 재시도 ...... 246
# 재시도 ...... 247
# 재시도 ...... 248
# 재시도 ...... 249
# 재시도 ...... 250
# 재시도 ...... 251
# 재시도 ...... 252
# 재시도 ...... 253
# 재시도 ...... 254
# 재시도 ...... 255
# 재시도 ...... 256
# 재시도 ...... 257
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 258
# 재시도 ...... 259
# 재시도 ...... 260
# 재시도 ...... 261
# 재시도 ...... 262
# 재시도 ...... 263
# 재시도 ...... 264
# 재시도 ...... 265
# 재시도 ...... 266
# 재시도 ...... 267
# 재시도 ...... 268
# 재시도 ...... 269
# 재시도 ...... 270
# 재시도 ...... 271
# 재시도 ...... 272
# 재시도 ...... 273
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 274
# 재시도 ...... 275
# 재시도 ...... 276
# 재시도 ...... 277
# 재시도 ...... 278
# 재시도 ...... 279
# 재시도 ...... 280
# 재시도 ...... 281
# 재시도 ...... 282
# 재시도 ...... 283
# 재시도 ...... 284
# 재시도 ...... 285
# 재시도 ...... 286
# 재시도 ...... 287
# 재시도 ...... 288
# 재시도 ...... 289
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 290
# 재시도 ...... 291
# 재시도 ...... 292
# 재시도 ...... 293
# 재시도 ...... 294
# 재시도 ...... 295
# 재시도 ...... 296
# 재시도 ...... 297
# 재시도 ...... 298
# 재시도 ...... 299
# 재시도 ...... 300
# 재시도 ...... 301
# 재시도 ...... 302
# 재시도 ...... 303
# 재시도 ...... 304
# 재시도 ...... 305
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 306
# 재시도 ...... 307
# 재시도 ...... 308
# 재시도 ...... 309
# 재시도 ...... 310
# 재시도 ...... 311
# 재시도 ...... 312
# 재시도 ...... 313
# 재시도 ...... 314
# 재시도 ...... 315
# 재시도 ...... 316
# 재시도 ...... 317
# 재시도 ...... 318
# 재시도 ...... 319
# 재시도 ...... 320
# 재시도 ...... 321
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 322
# 재시도 ...... 323
# 재시도 ...... 324
# 재시도 ...... 325
# 재시도 ...... 326
# 재시도 ...... 327
# 재시도 ...... 328
# 재시도 ...... 329
# 재시도 ...... 330
# 재시도 ...... 331
# 재시도 ...... 332
# 재시도 ...... 333
# 재시도 ...... 334
# 재시도 ...... 335
# 재시도 ...... 336
# 재시도 ...... 337
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 338
# 재시도 ...... 339
# 재시도 ...... 340
# 재시도 ...... 341
# 재시도 ...... 342
# 재시도 ...... 343
# 재시도 ...... 344
# 재시도 ...... 345
# 재시도 ...... 346
# 재시도 ...... 347
# 재시도 ...... 348
# 재시도 ...... 349
# 재시도 ...... 350
# 재시도 ...... 351
# 재시도 ...... 352
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 353
# 재시도 ...... 354
# 재시도 ...... 355
# 재시도 ...... 356
# 재시도 ...... 357
# 재시도 ...... 358
# 재시도 ...... 359
# 재시도 ...... 360
# 재시도 ...... 361
# 재시도 ...... 362
# 재시도 ...... 363
# 재시도 ...... 364
# 재시도 ...... 365
# 재시도 ...... 366
# 재시도 ...... 367
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 368
# 재시도 ...... 369
# 재시도 ...... 370
# 재시도 ...... 371
# 재시도 ...... 372
# 재시도 ...... 373
# 재시도 ...... 374
# 재시도 ...... 375
# 재시도 ...... 376
# 재시도 ...... 377
# 재시도 ...... 378
# 재시도 ...... 379
# 재시도 ...... 380
# 재시도 ...... 381
# 재시도 ...... 382
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 383
# 재시도 ...... 384
# 재시도 ...... 385
# 재시도 ...... 386
# 재시도 ...... 387
# 재시도 ...... 388
# 재시도 ...... 389
# 재시도 ...... 390
# 재시도 ...... 391
# 재시도 ...... 392
# 재시도 ...... 393
# 재시도 ...... 394
# 재시도 ...... 395
# 재시도 ...... 396
# 재시도 ...... 397
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 398
# 재시도 ...... 399
# 재시도 ...... 400
# 재시도 ...... 401
# 재시도 ...... 402
# 재시도 ...... 403
# 재시도 ...... 404
# 재시도 ...... 405
# 재시도 ...... 406
# 재시도 ...... 407
# 재시도 ...... 408
# 재시도 ...... 409
# 재시도 ...... 410
# 재시도 ...... 411
# 재시도 ...... 412
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 413
# 재시도 ...... 414
# 재시도 ...... 415
# 재시도 ...... 416
# 재시도 ...... 417
# 재시도 ...... 418
# 재시도 ...... 419
# 재시도 ...... 420
# 재시도 ...... 421
# 재시도 ...... 422
# 재시도 ...... 423
# 재시도 ...... 424
# 재시도 ...... 425
# 재시도 ...... 426
# 재시도 ...... 427
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 428
# 재시도 ...... 429
# 재시도 ...... 430
# 재시도 ...... 431
# 재시도 ...... 432
# 재시도 ...... 433
# 재시도 ...... 434
# 재시도 ...... 435
# 재시도 ...... 436
# 재시도 ...... 437
# 재시도 ...... 438
# 재시도 ...... 439
# 재시도 ...... 440
# 재시도 ...... 441
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 442
# 재시도 ...... 443
# 재시도 ...... 444
# 재시도 ...... 445
# 재시도 ...... 446
# 재시도 ...... 447
# 재시도 ...... 448
# 재시도 ...... 449
# 재시도 ...... 450
# 재시도 ...... 451
# 재시도 ...... 452
# 재시도 ...... 453
# 재시도 ...... 454
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 455
# 재시도 ...... 456
# 재시도 ...... 457
# 재시도 ...... 458
# 재시도 ...... 459
# 재시도 ...... 460
# 재시도 ...... 461
# 재시도 ...... 462
# 재시도 ...... 463
# 재시도 ...... 464
# 재시도 ...... 465
# 재시도 ...... 466
# 재시도 ...... 467
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 468
# 재시도 ...... 469
# 재시도 ...... 470
# 재시도 ...... 471
# 재시도 ...... 472
# 재시도 ...... 473
# 재시도 ...... 474
# 재시도 ...... 475
# 재시도 ...... 476
# 재시도 ...... 477
# 재시도 ...... 478
# 재시도 ...... 479
# 재시도 ...... 480
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 481
# 재시도 ...... 482
# 재시도 ...... 483
# 재시도 ...... 484
# 재시도 ...... 485
# 재시도 ...... 486
# 재시도 ...... 487
# 재시도 ...... 488
# 재시도 ...... 489
# 재시도 ...... 490
# 재시도 ...... 491
# 재시도 ...... 492
# 재시도 ...... 493
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 494
# 재시도 ...... 495
# 재시도 ...... 496
# 재시도 ...... 497
# 재시도 ...... 498
# 재시도 ...... 499
# 재시도 ...... 500
# 재시도 ...... 501
# 재시도 ...... 502
# 재시도 ...... 503
# 재시도 ...... 504
# 재시도 ...... 505
# 재시도 ...... 506
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 507
# 재시도 ...... 508
# 재시도 ...... 509
# 재시도 ...... 510
# 재시도 ...... 511
# 재시도 ...... 512
# 재시도 ...... 513
# 재시도 ...... 514
# 재시도 ...... 515
# 재시도 ...... 516
# 재시도 ...... 517
# 재시도 ...... 518
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 519
# 재시도 ...... 520
# 재시도 ...... 521
# 재시도 ...... 522
# 재시도 ...... 523
# 재시도 ...... 524
# 재시도 ...... 525
# 재시도 ...... 526
# 재시도 ...... 527
# 재시도 ...... 528
# 재시도 ...... 529
# 재시도 ...... 530
# 재시도 ...... 531
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 532
# 재시도 ...... 533
# 재시도 ...... 534
# 재시도 ...... 535
# 재시도 ...... 536
# 재시도 ...... 537
# 재시도 ...... 538
# 재시도 ...... 539
# 재시도 ...... 540
# 재시도 ...... 541
# 재시도 ...... 542
# 재시도 ...... 543
# 재시도 ...... 544
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 545
# 재시도 ...... 546
# 재시도 ...... 547
# 재시도 ...... 548
# 재시도 ...... 549
# 재시도 ...... 550
# 재시도 ...... 551
# 재시도 ...... 552
# 재시도 ...... 553
# 재시도 ...... 554
# 재시도 ...... 555
# 재시도 ...... 556
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 557
# 재시도 ...... 558
# 재시도 ...... 559
# 재시도 ...... 560
# 재시도 ...... 561
# 재시도 ...... 562
# 재시도 ...... 563
# 재시도 ...... 564
# 재시도 ...... 565
# 재시도 ...... 566
# 재시도 ...... 567
# 재시도 ...... 568
# 재시도 ...... 569
# 재시도 ...... 570
# 재시도 ...... 571
# 재시도 ...... 572
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 573
# 재시도 ...... 574
# 재시도 ...... 575
# 재시도 ...... 576
# 재시도 ...... 577
# 재시도 ...... 578
# 재시도 ...... 579
# 재시도 ...... 580
# 재시도 ...... 581
# 재시도 ...... 582
# 재시도 ...... 583
# 재시도 ...... 584
# 재시도 ...... 585
# 재시도 ...... 586
# 재시도 ...... 587
# 재시도 ...... 588
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 589
# 재시도 ...... 590
# 재시도 ...... 591
# 재시도 ...... 592
# 재시도 ...... 593
# 재시도 ...... 594
# 재시도 ...... 595
# 재시도 ...... 596
# 재시도 ...... 597
# 재시도 ...... 598
# 재시도 ...... 599
# 재시도 ...... 600
# 재시도 ...... 601
# 재시도 ...... 602
# 재시도 ...... 603
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 604
# 재시도 ...... 605
# 재시도 ...... 606
# 재시도 ...... 607
# 재시도 ...... 608
# 재시도 ...... 609
# 재시도 ...... 610
# 재시도 ...... 611
# 재시도 ...... 612
# 재시도 ...... 613
# 재시도 ...... 614
# 재시도 ...... 615
# 재시도 ...... 616
# 재시도 ...... 617
# 재시도 ...... 618
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 619
# 재시도 ...... 620
# 재시도 ...... 621
# 재시도 ...... 622
# 재시도 ...... 623
# 재시도 ...... 624
# 재시도 ...... 625
# 재시도 ...... 626
# 재시도 ...... 627
# 재시도 ...... 628
# 재시도 ...... 629
# 재시도 ...... 630
# 재시도 ...... 631
# 재시도 ...... 632
# 재시도 ...... 633
# 재시도 ...... 634
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 635
# 재시도 ...... 636
# 재시도 ...... 637
# 재시도 ...... 638
# 재시도 ...... 639
# 재시도 ...... 640
# 재시도 ...... 641
# 재시도 ...... 642
# 재시도 ...... 643
# 재시도 ...... 644
# 재시도 ...... 645
# 재시도 ...... 646
# 재시도 ...... 647
# 재시도 ...... 648
# 재시도 ...... 649
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 650
# 재시도 ...... 651
# 재시도 ...... 652
# 재시도 ...... 653
# 재시도 ...... 654
# 재시도 ...... 655
# 재시도 ...... 656
# 재시도 ...... 657
# 재시도 ...... 658
# 재시도 ...... 659
# 재시도 ...... 660
# 재시도 ...... 661
# 재시도 ...... 662
# 재시도 ...... 663
# 재시도 ...... 664
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 665
# 재시도 ...... 666
# 재시도 ...... 667
# 재시도 ...... 668
# 재시도 ...... 669
# 재시도 ...... 670
# 재시도 ...... 671
# 재시도 ...... 672
# 재시도 ...... 673
# 재시도 ...... 674
# 재시도 ...... 675
# 재시도 ...... 676
# 재시도 ...... 677
# 재시도 ...... 678
# 재시도 ...... 679
# 재시도 ...... 680
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 681
# 재시도 ...... 682
# 재시도 ...... 683
# 재시도 ...... 684
# 재시도 ...... 685
# 재시도 ...... 686
# 재시도 ...... 687
# 재시도 ...... 688
# 재시도 ...... 689
# 재시도 ...... 690
# 재시도 ...... 691
# 재시도 ...... 692
# 재시도 ...... 693
# 재시도 ...... 694
# 재시도 ...... 695
# 재시도 ...... 696
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 697
# 재시도 ...... 698
# 재시도 ...... 699
# 재시도 ...... 700
# 재시도 ...... 701
# 재시도 ...... 702
# 재시도 ...... 703
# 재시도 ...... 704
# 재시도 ...... 705
# 재시도 ...... 706
# 재시도 ...... 707
# 재시도 ...... 708
# 재시도 ...... 709
# 재시도 ...... 710
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 711
# 재시도 ...... 712
# 재시도 ...... 713
# 재시도 ...... 714
# 재시도 ...... 715
# 재시도 ...... 716
# 재시도 ...... 717
# 재시도 ...... 718
# 재시도 ...... 719
# 재시도 ...... 720
# 재시도 ...... 721
# 재시도 ...... 722
# 재시도 ...... 723
# 재시도 ...... 724
# 재시도 ...... 725
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 726
# 재시도 ...... 727
# 재시도 ...... 728
# 재시도 ...... 729
# 재시도 ...... 730
# 재시도 ...... 731
# 재시도 ...... 732
# 재시도 ...... 733
# 재시도 ...... 734
# 재시도 ...... 735
# 재시도 ...... 736
# 재시도 ...... 737
# 재시도 ...... 738
# 재시도 ...... 739
# 재시도 ...... 740
# 재시도 ...... 741
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 742
# 재시도 ...... 743
# 재시도 ...... 744
# 재시도 ...... 745
# 재시도 ...... 746
# 재시도 ...... 747
# 재시도 ...... 748
# 재시도 ...... 749
# 재시도 ...... 750
# 재시도 ...... 751
# 재시도 ...... 752
# 재시도 ...... 753
# 재시도 ...... 754
# 재시도 ...... 755
# 재시도 ...... 756
# 재시도 ...... 757
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 758
# 재시도 ...... 759
# 재시도 ...... 760
# 재시도 ...... 761
# 재시도 ...... 762
# 재시도 ...... 763
# 재시도 ...... 764
# 재시도 ...... 765
# 재시도 ...... 766
# 재시도 ...... 767
# 재시도 ...... 768
# 재시도 ...... 769
# 재시도 ...... 770
# 재시도 ...... 771
# 재시도 ...... 772
# 재시도 ...... 773
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 774
# 재시도 ...... 775
# 재시도 ...... 776
# 재시도 ...... 777
# 재시도 ...... 778
# 재시도 ...... 779
# 재시도 ...... 780
# 재시도 ...... 781
# 재시도 ...... 782
# 재시도 ...... 783
# 재시도 ...... 784
# 재시도 ...... 785
# 재시도 ...... 786
# 재시도 ...... 787
# 재시도 ...... 788
# 재시도 ...... 789
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 790
# 재시도 ...... 791
# 재시도 ...... 792
# 재시도 ...... 793
# 재시도 ...... 794
# 재시도 ...... 795
# 재시도 ...... 796
# 재시도 ...... 797
# 재시도 ...... 798
# 재시도 ...... 799
# 재시도 ...... 800
# 재시도 ...... 801
# 재시도 ...... 802
# 재시도 ...... 803
# 재시도 ...... 804
# 재시도 ...... 805
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 806
# 재시도 ...... 807
# 재시도 ...... 808
# 재시도 ...... 809
# 재시도 ...... 810
# 재시도 ...... 811
# 재시도 ...... 812
# 재시도 ...... 813
# 재시도 ...... 814
# 재시도 ...... 815
# 재시도 ...... 816
# 재시도 ...... 817
# 재시도 ...... 818
# 재시도 ...... 819
# 재시도 ...... 820
# 재시도 ...... 821
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 822
# 재시도 ...... 823
# 재시도 ...... 824
# 재시도 ...... 825
# 재시도 ...... 826
# 재시도 ...... 827
# 재시도 ...... 828
# 재시도 ...... 829
# 재시도 ...... 830
# 재시도 ...... 831
# 재시도 ...... 832
# 재시도 ...... 833
# 재시도 ...... 834
# 재시도 ...... 835
# 재시도 ...... 836
# 재시도 ...... 837
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 838
# 재시도 ...... 839
# 재시도 ...... 840
# 재시도 ...... 841
# 재시도 ...... 842
# 재시도 ...... 843
# 재시도 ...... 844
# 재시도 ...... 845
# 재시도 ...... 846
# 재시도 ...... 847
# 재시도 ...... 848
# 재시도 ...... 849
# 재시도 ...... 850
# 재시도 ...... 851
# 재시도 ...... 852
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 853
# 재시도 ...... 854
# 재시도 ...... 855
# 재시도 ...... 856
# 재시도 ...... 857
# 재시도 ...... 858
# 재시도 ...... 859
# 재시도 ...... 860
# 재시도 ...... 861
# 재시도 ...... 862
# 재시도 ...... 863
# 재시도 ...... 864
# 재시도 ...... 865
# 재시도 ...... 866
# 재시도 ...... 867
# 재시도 ...... 868
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 869
# 재시도 ...... 870
# 재시도 ...... 871
# 재시도 ...... 872
# 재시도 ...... 873
# 재시도 ...... 874
# 재시도 ...... 875
# 재시도 ...... 876
# 재시도 ...... 877
# 재시도 ...... 878
# 재시도 ...... 879
# 재시도 ...... 880
# 재시도 ...... 881
# 재시도 ...... 882
# 재시도 ...... 883
# 재시도 ...... 884
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 885
# 재시도 ...... 886
# 재시도 ...... 887
# 재시도 ...... 888
# 재시도 ...... 889
# 재시도 ...... 890
# 재시도 ...... 891
# 재시도 ...... 892
# 재시도 ...... 893
# 재시도 ...... 894
# 재시도 ...... 895
# 재시도 ...... 896
# 재시도 ...... 897
# 재시도 ...... 898
# 재시도 ...... 899
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 900
# 재시도 ...... 901
# 재시도 ...... 902
# 재시도 ...... 903
# 재시도 ...... 904
# 재시도 ...... 905
# 재시도 ...... 906
# 재시도 ...... 907
# 재시도 ...... 908
# 재시도 ...... 909
# 재시도 ...... 910
# 재시도 ...... 911
# 재시도 ...... 912
# 재시도 ...... 913
# 재시도 ...... 914
# 재시도 ...... 915
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 916
# 재시도 ...... 917
# 재시도 ...... 918
# 재시도 ...... 919
# 재시도 ...... 920
# 재시도 ...... 921
# 재시도 ...... 922
# 재시도 ...... 923
# 재시도 ...... 924
# 재시도 ...... 925
# 재시도 ...... 926
# 재시도 ...... 927
# 재시도 ...... 928
# 재시도 ...... 929
# 재시도 ...... 930
# 재시도 ...... 931
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 932
# 재시도 ...... 933
# 재시도 ...... 934
# 재시도 ...... 935
# 재시도 ...... 936
# 재시도 ...... 937
# 재시도 ...... 938
# 재시도 ...... 939
# 재시도 ...... 940
# 재시도 ...... 941
# 재시도 ...... 942
# 재시도 ...... 943
# 재시도 ...... 944
# 재시도 ...... 945
# 재시도 ...... 946
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 947
# 재시도 ...... 948
# 재시도 ...... 949
# 재시도 ...... 950
# 재시도 ...... 951
# 재시도 ...... 952
# 재시도 ...... 953
# 재시도 ...... 954
# 재시도 ...... 955
# 재시도 ...... 956
# 재시도 ...... 957
# 재시도 ...... 958
# 재시도 ...... 959
# 재시도 ...... 960
# 재시도 ...... 961
# 재시도 ...... 962
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 963
# 재시도 ...... 964
# 재시도 ...... 965
# 재시도 ...... 966
# 재시도 ...... 967
# 재시도 ...... 968
# 재시도 ...... 969
# 재시도 ...... 970
# 재시도 ...... 971
# 재시도 ...... 972
# 재시도 ...... 973
# 재시도 ...... 974
# 재시도 ...... 975
# 재시도 ...... 976
# 재시도 ...... 977
# 재시도 ...... 978
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 979
# 재시도 ...... 980
# 재시도 ...... 981
# 재시도 ...... 982
# 재시도 ...... 983
# 재시도 ...... 984
# 재시도 ...... 985
# 재시도 ...... 986
# 재시도 ...... 987
# 재시도 ...... 988
# 재시도 ...... 989
# 재시도 ...... 990
# 재시도 ...... 991
# 재시도 ...... 992
# 재시도 ...... 993
# 재시도 ...... 994
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 995
# 재시도 ...... 996
# 재시도 ...... 997
# 재시도 ...... 998
# 재시도 ...... 999
# 재시도 ...... 1000
# 재시도 ...... 1001
# 재시도 ...... 1002
# 재시도 ...... 1003
# 재시도 ...... 1004
# 재시도 ...... 1005
# 재시도 ...... 1006
# 재시도 ...... 1007
# 재시도 ...... 1008
# 재시도 ...... 1009
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 1010
# 재시도 ...... 1011
# 재시도 ...... 1012
# 재시도 ...... 1013
# 재시도 ...... 1014
# 재시도 ...... 1015
# 재시도 ...... 1016
# 재시도 ...... 1017
# 재시도 ...... 1018
# 재시도 ...... 1019
# 재시도 ...... 1020
# 재시도 ...... 1021
# 재시도 ...... 1022
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 1023
# 재시도 ...... 1024
# 재시도 ...... 1025
# 재시도 ...... 1026
# 재시도 ...... 1027
# 재시도 ...... 1028
# 재시도 ...... 1029
# 재시도 ...... 1030
# 재시도 ...... 1031
# 재시도 ...... 1032
# 재시도 ...... 1033
# 재시도 ...... 1034
# 재시도 ...... 1035
# 재시도 ...... 1036
# 재시도 ...... 1037
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 1038
# 재시도 ...... 1039
# 재시도 ...... 1040
# 재시도 ...... 1041
# 재시도 ...... 1042
# 재시도 ...... 1043
# 재시도 ...... 1044
# 재시도 ...... 1045
# 재시도 ...... 1046
# 재시도 ...... 1047
# 재시도 ...... 1048
# 재시도 ...... 1049
# 재시도 ...... 1050
# 재시도 ...... 1051
# 재시도 ...... 1052
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 1053
# 재시도 ...... 1054
# 재시도 ...... 1055
# 재시도 ...... 1056
# 재시도 ...... 1057
# 재시도 ...... 1058
# 재시도 ...... 1059
# 재시도 ...... 1060
# 재시도 ...... 1061
# 재시도 ...... 1062
# 재시도 ...... 1063
# 재시도 ...... 1064
# 재시도 ...... 1065
# 재시도 ...... 1066
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 1067
# 재시도 ...... 1068
# 재시도 ...... 1069
# 재시도 ...... 1070
# 재시도 ...... 1071
# 재시도 ...... 1072
# 재시도 ...... 1073
# 재시도 ...... 1074
# 재시도 ...... 1075
# 재시도 ...... 1076
# 재시도 ...... 1077
# 재시도 ...... 1078
# 재시도 ...... 1079
# 재시도 ...... 1080
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 1081
# 재시도 ...... 1082
# 재시도 ...... 1083
# 재시도 ...... 1084
# 재시도 ...... 1085
# 재시도 ...... 1086
# 재시도 ...... 1087
# 재시도 ...... 1088
# 재시도 ...... 1089
# 재시도 ...... 1090
# 재시도 ...... 1091
# 재시도 ...... 1092
# 재시도 ...... 1093
# 재시도 ...... 1094
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 1095
# 재시도 ...... 1096
# 재시도 ...... 1097
# 재시도 ...... 1098
# 재시도 ...... 1099
# 재시도 ...... 1100
# 재시도 ...... 1101
# 재시도 ...... 1102
# 재시도 ...... 1103
# 재시도 ...... 1104
# 재시도 ...... 1105
# 재시도 ...... 1106
# 재시도 ...... 1107
# 재시도 ...... 1108
# 열차 리스트가 초기화 되었습니다.
#
# 재시도 ...... 1109
# 재시도 ...... 1110
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 11
#       1 ## 지역명 예시
#       2 # ['수서','동탄','평택지제','천안아산','오송',
#       3 # '대전','김천(구미)','서대구','동대구','신경주',
#       4 # '울산(통도사)','부산','공주','익산','정읍','광주송정','나주','목포']
#       7 if __name__ == "__main__":
#       8     # driver = open_browser()
#       9     # driver = login(driver, '1986111308', 'zziny7622!')  ## 회원 번호, 비밀번호
#      10     # set_train(driver, "동대구", "수서", "20240310", 16)  ## ex) "동대구", "수서", "20240310", 16(탑승시각)
# ---> 11     start_search(first = 5, last = 7)  ## 화면 중 원하는 시간대 선택가능, 기본값 first = 1, last = 10
#      12     print('예약 완료')
#
# Cell In[63], line 70, in start_search(first, last)
#      68         pass
#      69     search_button_found = False
# ---> 70     time.sleep(2.5)
#      71     driver.refresh()
#      73 return driver
#
# KeyboardInterrupt:

# %%
git init
# Out:
#   Cell In[66], line 1
#     git init
#         ^
# SyntaxError: invalid syntax

# %%
# !pip install jupytext
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupytext in c:\users\user\appdata\roaming\python\python311\site-packages (1.16.1)
# Requirement already satisfied: markdown-it-py>=1.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from jupytext) (3.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\user\appdata\roaming\python\python311\site-packages (from jupytext) (0.4.0)
# Requirement already satisfied: nbformat in c:\program files\python311\lib\site-packages (from jupytext) (5.9.2)
# Requirement already satisfied: packaging in c:\program files\python311\lib\site-packages (from jupytext) (23.2)
# Requirement already satisfied: pyyaml in c:\program files\python311\lib\site-packages (from jupytext) (6.0.1)
# Requirement already satisfied: toml in c:\users\user\appdata\roaming\python\python311\site-packages (from jupytext) (0.10.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from markdown-it-py>=1.0->jupytext) (0.1.2)
# Requirement already satisfied: fastjsonschema in c:\program files\python311\lib\site-packages (from nbformat->jupytext) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\program files\python311\lib\site-packages (from nbformat->jupytext) (4.21.1)
# Requirement already satisfied: jupyter-core in c:\program files\python311\lib\site-packages (from nbformat->jupytext) (5.7.1)
# Requirement already satisfied: traitlets>=5.1 in c:\program files\python311\lib\site-packages (from nbformat->jupytext) (5.14.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\program files\python311\lib\site-packages (from jsonschema>=2.6->nbformat->jupytext) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\program files\python311\lib\site-packages (from jsonschema>=2.6->nbformat->jupytext) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\program files\python311\lib\site-packages (from jsonschema>=2.6->nbformat->jupytext) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\program files\python311\lib\site-packages (from jsonschema>=2.6->nbformat->jupytext) (0.17.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\program files\python311\lib\site-packages (from jupyter-core->nbformat->jupytext) (4.2.0)
# Requirement already satisfied: pywin32>=300 in c:\program files\python311\lib\site-packages (from jupyter-core->nbformat->jupytext) (306)

# %%
jupyter notebook --generate-config
# Out:
#   Cell In[70], line 1
#     jupyter notebook --generate-config
#             ^
# SyntaxError: invalid syntax
